# %% [markdown]
# # Part 2

# %%
import numpy as np

# %%
# Initialize deck
deck = list(range(1, 14)) * 4
#print(deck)

# %%
# Define function to deal cards to two players
def deal():
    # Initialize player hands
    p1 = []
    p2 = []
    
    # Initialize and shuffle deck
    deck = list(range(1, 14)) * 4
    np.random.shuffle(deck)
    
    # Deal cards to each player
    for i in range(len(deck)):
        if i % 2:
            p2.append(deck.pop(0))
        else:
            p1.append(deck.pop(0))
            
    return p1, p2

# %%
p1, p2 = deal()
#print('Player 1s hand:', p1, len(p1), sum(p1))
#print('Player 2s hand:', p2, len(p2), sum(p2))

# %% [markdown]
# ## Exercise #1

# %%
# Define function to play a single game
def play(games=1):
    Game_result = {}
    g =1
    # Deal cards to players, initialize claim lists
    while(games>0):
        p1, p2 = deal()
        p1_claim, p2_claim = [], []

        # Collect statistics
        S = {}
        #game_no = "Game "+str(games)
        #game_no = "Game ",games
        #print(game_no)
        # Calculate initial statistics
        
        S['initial_sums'] = (sum(p1), sum(p2))
        
        #print(Game_result)
        # Play!
        k = 1 # round counter
        i = 13 # maximum number of rounds
        number_of_tie = 0
        tie_in_final_sum = 0
        largest_total = 0
        print("Game: ",g)
        print("")
        while i > 0:
            # Print round
            #print('Round:', k)

            # Each player plays two cards
            p1_play = [p1.pop(0), p1.pop(0)]
            p2_play = [p2.pop(0), p2.pop(0)]
            i -= 1

            # Check for tie, and process accordingly
            if sum(p1_play) > sum(p2_play):
                if((sum(p1_play) + sum(p2_play))>largest_total):
                    largest_total = sum(p1_play) + sum(p2_play)
                # Player 1 wins hand, append cards to claim list
                p1_claim.extend(p1_play); p1_claim.extend(p2_play)
                #print('\tPlayer 1 wins hand (%d over %d), collects' % (sum(p1_play), sum(p2_play)), sum(p1_play) + sum(p2_play))
            elif sum(p2_play) > sum(p1_play):
                if((sum(p1_play) + sum(p2_play))>largest_total):
                    largest_total = sum(p1_play) + sum(p2_play)
                # Player 2 wins hand, append cards
                p2_claim.extend(p1_play); p2_claim.extend(p2_play)
               # print('\tPlayer 2 wins hand (%d over %d), collects' % (sum(p2_play), sum(p1_play)), sum(p1_play) + sum(p2_play))
            else:
                # Tie - Continue to play two cards until a player wins
                #print('\tTie:', sum(p1_play), 'vs.', sum(p2_play))
                number_of_tie += 1
                if i > 0:
                    while sum(p1_play[-2:]) == sum(p2_play[-2:]):
                        p1_play.extend([p1.pop(0), p1.pop(0)])
                        p2_play.extend([p2.pop(0), p2.pop(0)])
                        i -= 1

                        if sum(p1_play[-2:]) > sum(p2_play[-2:]):
                            if(sum(p1_play) + sum(p2_play))>largest_total:
                                largest_total = sum(p1_play) + sum(p2_play)
                            # Player 1 wins hand, append cards to claim list
                            p1_claim.extend(p1_play); p1_claim.extend(p2_play)
                            #print('\tPlayer 1 wins hand (%d over %d), collects' % (sum(p1_play[-2:]), sum(p2_play[-2:])), sum(p1_play) + sum(p2_play))
                        elif sum(p2_play[-2:]) > sum(p1_play[-2:]):
                            if(sum(p1_play) + sum(p2_play))>largest_total:
                                largest_total = sum(p1_play) + sum(p2_play)
                            # Player 2 wins hand, append cards to claim list
                            p2_claim.extend(p1_play); p2_claim.extend(p2_play)
                            #print('\tPlayer 2 wins hand (%d over %d), collects' % (sum(p2_play[-2:]), sum(p1_play[-2:])), sum(p1_play) + sum(p2_play))
                        else:
                            #print('\t\tAnother Tie:', sum(p1_play[-2:]), 'vs.', sum(p2_play[-2:]))
                            number_of_tie += 1
                            # Check for whether game ends in a tie - return cards to respective players
                            if i <= 0:
                                p1_claim.extend(p1_play)
                                p2_claim.extend(p2_play)
                                break
                else:
                    number_of_tie += 1
                    # Game ends in a tie - return cards to respective players
                    p1_claim.extend(p1_play)
                    p2_claim.extend(p2_play)

            # Increment round
            k += 1

        # Game over, compile results
        S['final_sums'] = (sum(p1_claim), sum(p2_claim))
        if S['final_sums'][0] != S['final_sums'][1]:
            # One player wins
            S['winner'] = 0 if S['final_sums'][0] > S['final_sums'][1] else 1
            #print('\nPlayer %d wins:' % [1, 2][S['winner']], S['final_sums'][S['winner']], 'to', S['final_sums'][1 - S['winner']])
        else:
            tie_in_final_sum += 1
            # Game is tied
            S['winner'] = -1
            #print('\nTie Game: %d to %d' % (S['final_sums'][0], S['final_sums'][1]))
        S['Number of ties'] = number_of_tie
        S['Maximum round total won'] = largest_total
        
        Game_result[g]= S
        #print(Game_result)
        print("Number of ties: ",number_of_tie)
        #print("Largest total in rounds was: ",largest_total)
        print("")
        if(tie_in_final_sum>0):
            print("There was a tie in final sum")
            print("")
        games -= 1
        g += 1
        # Return results
    #return Game_result

# %% [markdown]
# ### Step 1.1

# %%
play(5)
# Out:
# Game:  1
#
# Number of ties:  1
#
# Game:  2
#
# Number of ties:  1
#
# Game:  3
#
# Number of ties:  0
#
# Game:  4
#
# Number of ties:  3
#
# Game:  5
#
# Number of ties:  1

# %%
# Define function to play a single game
def play_1_2(games=1):
    Game_result = {}
    g =1
    # Deal cards to players, initialize claim lists
    while(games>0):
        p1, p2 = deal()
        p1_claim, p2_claim = [], []

        # Collect statistics
        S = {}
        #game_no = "Game "+str(games)
        #game_no = "Game ",games
        #print(game_no)
        # Calculate initial statistics
        
        S['initial_sums'] = (sum(p1), sum(p2))
        
        #print(Game_result)
        # Play!
        k = 1 # round counter
        i = 13 # maximum number of rounds
        number_of_tie = 0
        tie_in_final_sum = 0
        largest_total = 0
        print("Game: ",g)
        print("")
        while i > 0:
            # Print round
            #print('Round:', k)

            # Each player plays two cards
            p1_play = [p1.pop(0), p1.pop(0)]
            p2_play = [p2.pop(0), p2.pop(0)]
            i -= 1

            # Check for tie, and process accordingly
            if sum(p1_play) > sum(p2_play):
                if((sum(p1_play) + sum(p2_play))>largest_total):
                    largest_total = sum(p1_play) + sum(p2_play)
                # Player 1 wins hand, append cards to claim list
                p1_claim.extend(p1_play); p1_claim.extend(p2_play)
                #print('\tPlayer 1 wins hand (%d over %d), collects' % (sum(p1_play), sum(p2_play)), sum(p1_play) + sum(p2_play))
            elif sum(p2_play) > sum(p1_play):
                if((sum(p1_play) + sum(p2_play))>largest_total):
                    largest_total = sum(p1_play) + sum(p2_play)
                # Player 2 wins hand, append cards
                p2_claim.extend(p1_play); p2_claim.extend(p2_play)
               # print('\tPlayer 2 wins hand (%d over %d), collects' % (sum(p2_play), sum(p1_play)), sum(p1_play) + sum(p2_play))
            else:
                # Tie - Continue to play two cards until a player wins
                #print('\tTie:', sum(p1_play), 'vs.', sum(p2_play))
                number_of_tie += 1
                if i > 0:
                    while sum(p1_play[-2:]) == sum(p2_play[-2:]):
                        p1_play.extend([p1.pop(0), p1.pop(0)])
                        p2_play.extend([p2.pop(0), p2.pop(0)])
                        i -= 1

                        if sum(p1_play[-2:]) > sum(p2_play[-2:]):
                            if(sum(p1_play) + sum(p2_play))>largest_total:
                                largest_total = sum(p1_play) + sum(p2_play)
                            # Player 1 wins hand, append cards to claim list
                            p1_claim.extend(p1_play); p1_claim.extend(p2_play)
                            #print('\tPlayer 1 wins hand (%d over %d), collects' % (sum(p1_play[-2:]), sum(p2_play[-2:])), sum(p1_play) + sum(p2_play))
                        elif sum(p2_play[-2:]) > sum(p1_play[-2:]):
                            if(sum(p1_play) + sum(p2_play))>largest_total:
                                largest_total = sum(p1_play) + sum(p2_play)
                            # Player 2 wins hand, append cards to claim list
                            p2_claim.extend(p1_play); p2_claim.extend(p2_play)
                            #print('\tPlayer 2 wins hand (%d over %d), collects' % (sum(p2_play[-2:]), sum(p1_play[-2:])), sum(p1_play) + sum(p2_play))
                        else:
                            #print('\t\tAnother Tie:', sum(p1_play[-2:]), 'vs.', sum(p2_play[-2:]))
                            number_of_tie += 1
                            # Check for whether game ends in a tie - return cards to respective players
                            if i <= 0:
                                p1_claim.extend(p1_play)
                                p2_claim.extend(p2_play)
                                break
                else:
                    number_of_tie += 1
                    # Game ends in a tie - return cards to respective players
                    p1_claim.extend(p1_play)
                    p2_claim.extend(p2_play)

            # Increment round
            k += 1

        # Game over, compile results
        S['final_sums'] = (sum(p1_claim), sum(p2_claim))
        if S['final_sums'][0] != S['final_sums'][1]:
            # One player wins
            S['winner'] = 0 if S['final_sums'][0] > S['final_sums'][1] else 1
            #print('\nPlayer %d wins:' % [1, 2][S['winner']], S['final_sums'][S['winner']], 'to', S['final_sums'][1 - S['winner']])
        else:
            tie_in_final_sum += 1
            # Game is tied
            S['winner'] = -1
            #print('\nTie Game: %d to %d' % (S['final_sums'][0], S['final_sums'][1]))
        S['Number of ties'] = number_of_tie
        S['Maximum round total won'] = largest_total
        
        Game_result[g]= S
        #print(Game_result)
        #print("Number of ties: ",number_of_tie)
        print("Largest total in rounds was: ",largest_total)
        print("")
        if(tie_in_final_sum>0):
            print("There was a tie in final sum")
            print("")
        games -= 1
        g += 1
        # Return results
    #return Game_result

# %% [markdown]
# ### Step 1.2

# %%
play_1_2(5)
# Out:
# Game:  1
#
# Largest total in rounds was:  63
#
# Game:  2
#
# Largest total in rounds was:  50
#
# Game:  3
#
# Largest total in rounds was:  48
#
# Game:  4
#
# Largest total in rounds was:  56
#
# Game:  5
#
# Largest total in rounds was:  63

# %% [markdown]
# ### Step 1.3

# %%
# Define function to play a single game
def play_1_3(games=1):
    Game_result = {}
    g =1
    # Deal cards to players, initialize claim lists
    while(games>0):
        p1, p2 = deal()
        p1_claim, p2_claim = [], []

        # Collect statistics
        S = {}
        #game_no = "Game "+str(games)
        #game_no = "Game ",games
        #print(game_no)
        # Calculate initial statistics
        
        S['initial_sums'] = (sum(p1), sum(p2))
        
        #print(Game_result)
        # Play!
        k = 1 # round counter
        i = 13 # maximum number of rounds
        number_of_tie = 0
        tie_in_final_sum = 0
        largest_total = 0
        print("Game: ",g)
        print("")
        while i > 0:
            # Print round
            print('Round:', k)

            # Each player plays two cards
            p1_play = [p1.pop(0), p1.pop(0)]
            p2_play = [p2.pop(0), p2.pop(0)]
            i -= 1

            # Check for tie, and process accordingly
            if sum(p1_play) > sum(p2_play):
                if((sum(p1_play) + sum(p2_play))>largest_total):
                    largest_total = sum(p1_play) + sum(p2_play)
                # Player 1 wins hand, append cards to claim list
                p1_claim.extend(p1_play); p1_claim.extend(p2_play)
                print('\tPlayer 1 wins hand (%d over %d), collects' % (sum(p1_play), sum(p2_play)), sum(p1_play) + sum(p2_play))
            elif sum(p2_play) > sum(p1_play):
                if((sum(p1_play) + sum(p2_play))>largest_total):
                    largest_total = sum(p1_play) + sum(p2_play)
                # Player 2 wins hand, append cards
                p2_claim.extend(p1_play); p2_claim.extend(p2_play)
                print('\tPlayer 2 wins hand (%d over %d), collects' % (sum(p2_play), sum(p1_play)), sum(p1_play) + sum(p2_play))
            else:
                # Tie - Continue to play two cards until a player wins
                print('\tTie:', sum(p1_play), 'vs.', sum(p2_play))
                number_of_tie += 1
                if i > 0:
                    while sum(p1_play[-2:]) == sum(p2_play[-2:]):
                        p1_play.extend([p1.pop(0), p1.pop(0)])
                        p2_play.extend([p2.pop(0), p2.pop(0)])
                        i -= 1

                        if sum(p1_play[-2:]) > sum(p2_play[-2:]):
                            if(sum(p1_play) + sum(p2_play))>largest_total:
                                largest_total = sum(p1_play) + sum(p2_play)
                            # Player 1 wins hand, append cards to claim list
                            p1_claim.extend(p1_play); p1_claim.extend(p2_play)
                            print('\tPlayer 1 wins hand (%d over %d), collects' % (sum(p1_play[-2:]), sum(p2_play[-2:])), sum(p1_play) + sum(p2_play))
                        elif sum(p2_play[-2:]) > sum(p1_play[-2:]):
                            if(sum(p1_play) + sum(p2_play))>largest_total:
                                largest_total = sum(p1_play) + sum(p2_play)
                            # Player 2 wins hand, append cards to claim list
                            p2_claim.extend(p1_play); p2_claim.extend(p2_play)
                            print('\tPlayer 2 wins hand (%d over %d), collects' % (sum(p2_play[-2:]), sum(p1_play[-2:])), sum(p1_play) + sum(p2_play))
                        else:
                            print('\t\tAnother Tie:', sum(p1_play[-2:]), 'vs.', sum(p2_play[-2:]))
                            number_of_tie += 1
                            # Check for whether game ends in a tie - return cards to respective players
                            if i <= 0:
                                p1_claim.extend(p1_play)
                                p2_claim.extend(p2_play)
                                break
                else:
                    number_of_tie += 1
                    # Game ends in a tie - return cards to respective players
                    p1_claim.extend(p1_play)
                    p2_claim.extend(p2_play)

            # Increment round
            k += 1

        # Game over, compile results
        S['final_sums'] = (sum(p1_claim), sum(p2_claim))
        if S['final_sums'][0] != S['final_sums'][1]:
            # One player wins
            S['winner'] = 0 if S['final_sums'][0] > S['final_sums'][1] else 1
            print('\nPlayer %d wins:' % [1, 2][S['winner']], S['final_sums'][S['winner']], 'to', S['final_sums'][1 - S['winner']])
        else:
            tie_in_final_sum += 1
            # Game is tied
            S['winner'] = -1
            print('\nTie Game: %d to %d' % (S['final_sums'][0], S['final_sums'][1]))
        S['Number of ties'] = number_of_tie
        S['Maximum round total won'] = largest_total
        
        Game_result[g]= S
        #print(Game_result)
        print("Number of ties: ",number_of_tie)
        print("Largest total in rounds was: ",largest_total)
        print("")
        if(tie_in_final_sum>0):
            print("There was a tie in final sum")
            print("")
        games -= 1
        g += 1
        # Return results
    return Game_result

# %% [markdown]
# ### Step 1.4

# %%
play_1_3()
# Out:
# Game:  1
#
# Round: 1
# 	Player 1 wins hand (22 over 7), collects 29
# Round: 2
# 	Player 2 wins hand (15 over 6), collects 21
# Round: 3
# 	Player 1 wins hand (17 over 16), collects 33
# Round: 4
# 	Player 2 wins hand (20 over 15), collects 35
# Round: 5
# 	Player 2 wins hand (17 over 11), collects 28
# Round: 6
# 	Player 2 wins hand (15 over 9), collects 24
# Round: 7
# 	Player 2 wins hand (15 over 5), collects 20
# Round: 8
# 	Player 2 wins hand (12 over 11), collects 23
# Round: 9
# 	Player 2 wins hand (21 over 13), collects 34
# Round: 10
# 	Player 2 wins hand (22 over 10), collects 32
# Round: 11
# 	Player 1 wins hand (17 over 13), collects 30
# Round: 12
# 	Player 1 wins hand (14 over 13), collects 27
# Round: 13
# 	Player 2 wins hand (16 over 12), collects 28
#
# Player 2 wins: 245 to 119
# Number of ties:  0
# Largest total in rounds was:  35
# {1: {'initial_sums': (162, 202),
#   'final_sums': (119, 245),
#   'winner': 1,
#   'Number of ties': 0,
#   'Maximum round total won': 35}}

# %%
play_1_3(5)
# Out:
# Game:  1
#
# Round: 1
# 	Player 2 wins hand (14 over 7), collects 21
# Round: 2
# 	Player 2 wins hand (18 over 16), collects 34
# Round: 3
# 	Player 2 wins hand (7 over 6), collects 13
# Round: 4
# 	Player 1 wins hand (24 over 12), collects 36
# Round: 5
# 	Player 1 wins hand (21 over 7), collects 28
# Round: 6
# 	Tie: 13 vs. 13
# 	Player 1 wins hand (21 over 13), collects 60
# Round: 7
# 	Player 2 wins hand (9 over 5), collects 14
# Round: 8
# 	Player 2 wins hand (17 over 9), collects 26
# Round: 9
# 	Player 1 wins hand (20 over 14), collects 34
# Round: 10
# 	Player 1 wins hand (22 over 18), collects 40
# Round: 11
# 	Player 1 wins hand (15 over 14), collects 29
# Round: 12
# 	Player 1 wins hand (16 over 13), collects 29
#
# Player 1 wins: 256 to 108
# Number of ties:  1
# Largest total in rounds was:  60
#
# Game:  2
#
# Round: 1
# 	Player 2 wins hand (21 over 17), collects 38
# Round: 2
# 	Player 2 wins hand (19 over 16), collects 35
# Round: 3
# 	Player 2 wins hand (15 over 10), collects 25
# Round: 4
# 	Player 1 wins hand (17 over 9), collects 26
# Round: 5
# 	Player 1 wins hand (8 over 7), collects 15
# Round: 6
# 	Player 2 wins hand (21 over 13), collects 34
# Round: 7
# 	Player 1 wins hand (15 over 13), collects 28
# Round: 8
# 	Player 2 wins hand (21 over 5), collects 26
# Round: 9
# 	Player 1 wins hand (14 over 10), collects 24
# Round: 10
# 	Player 2 wins hand (15 over 13), collects 28
# Round: 11
# 	Player 2 wins hand (25 over 11), collects 36
# Round: 12
# 	Player 1 wins hand (20 over 12), collects 32
# Round: 13
# 	Player 2 wins hand (9 over 8), collects 17
#
# Player 2 wins: 239 to 125
# Number of ties:  0
# Largest total in rounds was:  38
#
# Game:  3
#
# Round: 1
# 	Player 2 wins hand (22 over 12), collects 34
# Round: 2
# 	Player 1 wins hand (13 over 8), collects 21
# Round: 3
# 	Player 1 wins hand (25 over 13), collects 38
# Round: 4
# 	Player 2 wins hand (14 over 3), collects 17
# Round: 5
# 	Player 2 wins hand (15 over 14), collects 29
# Round: 6
# 	Player 1 wins hand (17 over 3), collects 20
# Round: 7
# 	Player 1 wins hand (14 over 11), collects 25
# Round: 8
# 	Player 1 wins hand (19 over 16), collects 35
# Round: 9
# 	Player 2 wins hand (17 over 10), collects 27
# Round: 10
# 	Player 2 wins hand (12 over 8), collects 20
# Round: 11
# 	Player 1 wins hand (21 over 20), collects 41
# Round: 12
# 	Player 2 wins hand (19 over 14), collects 33
# Round: 13
# 	Tie: 12 vs. 12
#
# Player 1 wins: 192 to 172
# Number of ties:  2
# Largest total in rounds was:  41
#
# Game:  4
#
# Round: 1
# 	Player 1 wins hand (21 over 8), collects 29
# Round: 2
# 	Player 2 wins hand (14 over 9), collects 23
# Round: 3
# 	Player 2 wins hand (23 over 12), collects 35
# Round: 4
# 	Player 2 wins hand (20 over 7), collects 27
# Round: 5
# 	Player 2 wins hand (14 over 11), collects 25
# Round: 6
# 	Player 2 wins hand (20 over 18), collects 38
# Round: 7
# 	Player 1 wins hand (18 over 16), collects 34
# Round: 8
# 	Player 1 wins hand (19 over 8), collects 27
# Round: 9
# 	Player 1 wins hand (14 over 12), collects 26
# Round: 10
# 	Player 2 wins hand (7 over 4), collects 11
# Round: 11
# 	Player 1 wins hand (20 over 12), collects 32
# Round: 12
# 	Player 2 wins hand (21 over 12), collects 33
# Round: 13
# 	Player 2 wins hand (16 over 8), collects 24
#
# Player 2 wins: 216 to 148
# Number of ties:  0
# Largest total in rounds was:  38
#
# Game:  5
#
# Round: 1
# 	Player 2 wins hand (15 over 5), collects 20
# Round: 2
# 	Player 1 wins hand (18 over 15), collects 33
# Round: 3
# 	Player 2 wins hand (11 over 6), collects 17
# Round: 4
# 	Player 2 wins hand (16 over 10), collects 26
# Round: 5
# 	Tie: 16 vs. 16
# 	Player 1 wins hand (23 over 19), collects 74
# Round: 6
# 	Player 1 wins hand (7 over 5), collects 12
# Round: 7
# 	Player 2 wins hand (10 over 9), collects 19
# Round: 8
# 	Player 2 wins hand (20 over 13), collects 33
# Round: 9
# 	Player 1 wins hand (20 over 17), collects 37
# Round: 10
# 	Player 1 wins hand (20 over 19), collects 39
# Round: 11
# 	Player 1 wins hand (17 over 5), collects 22
# Round: 12
# 	Player 2 wins hand (18 over 14), collects 32
#
# Player 1 wins: 217 to 147
# Number of ties:  1
# Largest total in rounds was:  74
# {1: {'initial_sums': (195, 169),
#   'final_sums': (256, 108),
#   'winner': 0,
#   'Number of ties': 1,
#   'Maximum round total won': 60},
#  2: {'initial_sums': (167, 197),
#   'final_sums': (125, 239),
#   'winner': 1,
#   'Number of ties': 0,
#   'Maximum round total won': 38},
#  3: {'initial_sums': (182, 182),
#   'final_sums': (192, 172),
#   'winner': 0,
#   'Number of ties': 2,
#   'Maximum round total won': 41},
#  4: {'initial_sums': (173, 191),
#   'final_sums': (148, 216),
#   'winner': 1,
#   'Number of ties': 0,
#   'Maximum round total won': 38},
#  5: {'initial_sums': (178, 186),
#   'final_sums': (217, 147),
#   'winner': 0,
#   'Number of ties': 1,
#   'Maximum round total won': 74}}

# %% [markdown]
# ## Exercise #2

# %%
# Define function to play a single game
def play1000(games=1):               # taking games argument with default value 1
    Game_result = {}                 #initiating empty dictionary to fill it with results of diffrent games
    g =1                             # initiating variable g which will give counter for game number
    # Deal cards to players, initialize claim lists
    while(games>0):                  #Looping till we play the number of games desired
        p1, p2 = deal()
        p1_claim, p2_claim = [], []

        # Collect statistics
        S = {}
        #game_no = "Game "+str(games)
        #game_no = "Game ",games
        #print(game_no)
        # Calculate initial statistics
        player_1 = 0
        player_2 = 0 
        S['initial_sums'] = (sum(p1), sum(p2))
        
        #print(Game_result)
        # Play!
        k = 1 # round counter
        i = 13 # maximum number of rounds
        number_of_tie = 0            #initiating variable as 0 to count number of ties
        tie_in_final_sum = 0         #initiating variable if final sum is tie   
        largest_total = 0            #initiating variable to count largest total 
        #print("Game: ",g)
        #print("")
        while i > 0:
            # Print round
            #print('Round:', k)

            # Each player plays two cards
            p1_play = [p1.pop(0), p1.pop(0)]
            p2_play = [p2.pop(0), p2.pop(0)]
            i -= 1

            # Check for tie, and process accordingly
            if sum(p1_play) > sum(p2_play):
                if((sum(p1_play) + sum(p2_play))>largest_total):
                    largest_total = sum(p1_play) + sum(p2_play)           #giving appropriate value to largest_total variable
                # Player 1 wins hand, append cards to claim list
                p1_claim.extend(p1_play); p1_claim.extend(p2_play)
                #print('\tPlayer 1 wins hand (%d over %d), collects' % (sum(p1_play), sum(p2_play)), sum(p1_play) + sum(p2_play))
            elif sum(p2_play) > sum(p1_play):
                if((sum(p1_play) + sum(p2_play))>largest_total):
                    largest_total = sum(p1_play) + sum(p2_play)           #giving appropriate value to largest_total variable
                # Player 2 wins hand, append cards
                p2_claim.extend(p1_play); p2_claim.extend(p2_play)
                #print('\tPlayer 2 wins hand (%d over %d), collects' % (sum(p2_play), sum(p1_play)), sum(p1_play) + sum(p2_play))
            else:
                # Tie - Continue to play two cards until a player wins
                #print('\tTie:', sum(p1_play), 'vs.', sum(p2_play))
                number_of_tie += 1                                        #incrementing number_of_tie counter 
                if i > 0:
                    while sum(p1_play[-2:]) == sum(p2_play[-2:]):
                        p1_play.extend([p1.pop(0), p1.pop(0)])
                        p2_play.extend([p2.pop(0), p2.pop(0)])
                        i -= 1

                        if sum(p1_play[-2:]) > sum(p2_play[-2:]):
                            if(sum(p1_play) + sum(p2_play))>largest_total:
                                largest_total = sum(p1_play) + sum(p2_play)   #giving appropriate value to largest_total variable
                            # Player 1 wins hand, append cards to claim list
                            p1_claim.extend(p1_play); p1_claim.extend(p2_play)
                            #print('\tPlayer 1 wins hand (%d over %d), collects' % (sum(p1_play[-2:]), sum(p2_play[-2:])), sum(p1_play) + sum(p2_play))
                        elif sum(p2_play[-2:]) > sum(p1_play[-2:]):
                            if(sum(p1_play) + sum(p2_play))>largest_total:
                                largest_total = sum(p1_play) + sum(p2_play)   #giving appropriate value to largest_total variable
                            # Player 2 wins hand, append cards to claim list
                            p2_claim.extend(p1_play); p2_claim.extend(p2_play)
                            #print('\tPlayer 2 wins hand (%d over %d), collects' % (sum(p2_play[-2:]), sum(p1_play[-2:])), sum(p1_play) + sum(p2_play))
                        else:
                            #print('\t\tAnother Tie:', sum(p1_play[-2:]), 'vs.', sum(p2_play[-2:]))
                            number_of_tie += 1                                #incrementing number_of_tie counter 
                            # Check for whether game ends in a tie - return cards to respective players
                            if i <= 0:
                                p1_claim.extend(p1_play)
                                p2_claim.extend(p2_play)
                                break
                else:                                                         #incrementing number_of_tie counter    
                    number_of_tie += 1                                      
                    # Game ends in a tie - return cards to respective players
                    p1_claim.extend(p1_play)
                    p2_claim.extend(p2_play)

            # Increment round
            k += 1

        # Game over, compile results
        S['final_sums'] = (sum(p1_claim), sum(p2_claim))
        S['player1_sum'] = sum(p1_claim); 
        S['player2_sum'] = sum(p2_claim);
        if S['final_sums'][0] != S['final_sums'][1]:
            # One player wins
            S['winner'] = 0 if S['final_sums'][0] > S['final_sums'][1] else 1
            #print('\nPlayer %d wins:' % [1, 2][S['winner']], S['final_sums'][S['winner']], 'to', S['final_sums'][1 - S['winner']])
        else:
            tie_in_final_sum += 1                                            #incrementing tie_in_final_sum counter 
            # Game is tied
            S['winner'] = -1
            #print('\nTie Game: %d to %d' % (S['final_sums'][0], S['final_sums'][1]))
        S['Number of ties'] = number_of_tie                                  #adding number of ties to dicitionary S
        S['Maximum round total won'] = largest_total                         #adding maximum round total won to dicitionary S
        
        Game_result[g]= S                                                    #adding dictionary S in dictionary Game_result
        #print(Game_result)
        #print("Number of ties: ",number_of_tie)
        #print("Largest total in rounds was: ",largest_total)
        #print("")
        #if(tie_in_final_sum>0):
            #print("There was a tie in final sum")
            #print("")
        games -= 1                                                          #Decrementing games counter for while loop 
        g += 1                                                              #Incrementing game counter to tell which game is going 
        # Return results
    return Game_result

# %%
import pandas as pd
df = pd.DataFrame(play1000(1000))
df_trial = df.T

# %%
df_trial.head(10)
# Out:
#    Maximum round total won Number of ties  final_sums initial_sums  \
# 1                       58              3  (216, 148)   (185, 179)
# 2                       67              1  (124, 240)   (164, 200)
# 3                       58              1  (195, 169)   (179, 185)
# 4                       44              0   (276, 88)   (200, 164)
# 5                       42              2  (171, 193)   (171, 193)
# 6                       37              0   (64, 300)   (154, 210)
# 7                       65              2  (148, 216)   (167, 197)
# 8                       57              1   (94, 270)   (139, 225)
# 9                       43              0  (171, 193)   (182, 182)
# 10                      59              2  (207, 157)   (179, 185)
#
#    player1_sum player2_sum winner        outcome winning_total losing_total
# 1          216         148      0  Player 1 wins           216          148
# 2          124         240      1  Player 2 wins           240          124
# 3          195         169      0  Player 1 wins           195          169
# 4          276          88      0  Player 1 wins           276           88
# 5          171         193      1  Player 2 wins           193          171
# 6           64         300      1  Player 2 wins           300           64
# 7          148         216      1  Player 2 wins           216          148
# 8           94         270      1  Player 2 wins           270           94
# 9          171         193      1  Player 2 wins           193          171
# 10         207         157      0  Player 1 wins           207          157

# %%
df_trial.tail(10)
# Out:
#      Maximum round total won Number of ties  final_sums initial_sums  \
# 991                       73              2  (192, 172)   (189, 175)
# 992                       37              0  (188, 176)   (194, 170)
# 993                       54              1  (180, 184)   (191, 173)
# 994                       44              0  (123, 241)   (179, 185)
# 995                       39              0  (169, 195)   (182, 182)
# 996                       42              0  (264, 100)   (219, 145)
# 997                       57              1   (76, 288)   (160, 204)
# 998                       45              0  (213, 151)   (173, 191)
# 999                       68              2  (168, 196)   (171, 193)
# 1000                      54              2  (191, 173)   (194, 170)
#
#      player1_sum player2_sum winner
# 991          192         172      0
# 992          188         176      0
# 993          180         184      1
# 994          123         241      1
# 995          169         195      1
# 996          264         100      0
# 997           76         288      1
# 998          213         151      0
# 999          168         196      1
# 1000         191         173      0

# %% [markdown]
# ## Exercise #3

# %% [markdown]
# ### Step 3.1

# %%
df_trial.loc[df_trial.player1_sum > df_trial.player2_sum, 'outcome'] = 'Player 1 wins' 
df_trial.loc[df_trial.player2_sum > df_trial.player1_sum, 'outcome'] = 'Player 2 wins'
df_trial.loc[df_trial.player2_sum == df_trial.player1_sum, 'outcome'] = 'Tie'

# %% [markdown]
# ### Step 3.2

# %%
df_trial.loc[df_trial.player1_sum > df_trial.player2_sum, 'winning_total'] = df_trial.player1_sum
df_trial.loc[df_trial.player1_sum > df_trial.player2_sum, 'losing_total'] = df_trial.player2_sum
df_trial.loc[df_trial.player2_sum > df_trial.player1_sum, 'winning_total'] = df_trial.player2_sum
df_trial.loc[df_trial.player2_sum > df_trial.player1_sum, 'losing_total'] = df_trial.player1_sum
df_trial.loc[df_trial.player2_sum == df_trial.player1_sum, 'winning_total'] = np.nan
df_trial.loc[df_trial.player2_sum == df_trial.player1_sum, 'losing_total'] = np.nan

# %% [markdown]
# ### Step 3.3

# %%
df_trial.head(10)
# Out:
#    Maximum round total won Number of ties  final_sums initial_sums  \
# 1                       58              3  (216, 148)   (185, 179)
# 2                       67              1  (124, 240)   (164, 200)
# 3                       58              1  (195, 169)   (179, 185)
# 4                       44              0   (276, 88)   (200, 164)
# 5                       42              2  (171, 193)   (171, 193)
# 6                       37              0   (64, 300)   (154, 210)
# 7                       65              2  (148, 216)   (167, 197)
# 8                       57              1   (94, 270)   (139, 225)
# 9                       43              0  (171, 193)   (182, 182)
# 10                      59              2  (207, 157)   (179, 185)
#
#    player1_sum player2_sum winner        outcome winning_total losing_total
# 1          216         148      0  Player 1 wins           216          148
# 2          124         240      1  Player 2 wins           240          124
# 3          195         169      0  Player 1 wins           195          169
# 4          276          88      0  Player 1 wins           276           88
# 5          171         193      1  Player 2 wins           193          171
# 6           64         300      1  Player 2 wins           300           64
# 7          148         216      1  Player 2 wins           216          148
# 8           94         270      1  Player 2 wins           270           94
# 9          171         193      1  Player 2 wins           193          171
# 10         207         157      0  Player 1 wins           207          157

# %%
df_trial['outcome'].value_counts()
# Out:
# Player 2 wins    506
# Player 1 wins    483
# Tie               11
# Name: outcome, dtype: int64

# %%
df_trial[df_trial['outcome']=='Tie']
# Out:
#     Maximum round total won Number of ties  final_sums initial_sums  \
# 169                      41              2  (182, 182)   (191, 173)
# 209                      60              2  (182, 182)   (163, 201)
# 279                      42              0  (182, 182)   (174, 190)
# 289                      57              1  (182, 182)   (173, 191)
# 290                      45              1  (182, 182)   (190, 174)
# 526                      64              2  (182, 182)   (191, 173)
# 530                      40              0  (182, 182)   (183, 181)
# 657                      38              0  (182, 182)   (192, 172)
# 788                      56              2  (182, 182)   (185, 179)
# 836                      37              0  (182, 182)   (195, 169)
# 851                      60              1  (182, 182)   (184, 180)
#
#     player1_sum player2_sum winner outcome winning_total losing_total
# 169         182         182     -1     Tie           NaN          NaN
# 209         182         182     -1     Tie           NaN          NaN
# 279         182         182     -1     Tie           NaN          NaN
# 289         182         182     -1     Tie           NaN          NaN
# 290         182         182     -1     Tie           NaN          NaN
# 526         182         182     -1     Tie           NaN          NaN
# 530         182         182     -1     Tie           NaN          NaN
# 657         182         182     -1     Tie           NaN          NaN
# 788         182         182     -1     Tie           NaN          NaN
# 836         182         182     -1     Tie           NaN          NaN
# 851         182         182     -1     Tie           NaN          NaN

# %% [markdown]
# ### Step 3.4

# %%
df_trial['winning_total'].describe()
# Out:
# count     989
# unique    134
# top       210
# freq       20
# Name: winning_total, dtype: int64

# %%
df_trial['winning_total'].min()
# Out:
# 183

# %%
df_trial['winning_total'].mean()
# Out:
# 225.8382204246714

# %%
df_trial['winning_total'].max()
# Out:
# 364

# %%
df_trial['winning_total'].std()
# Out:
# 31.72982025140044

# %%
df_trial.sort_values(by = 'winning_total', ascending = False).head(10)
# Out:
#     Maximum round total won Number of ties final_sums initial_sums  \
# 395                      57              2   (0, 364)   (151, 213)
# 469                      61              2  (18, 346)   (170, 194)
# 979                      46              1  (341, 23)   (220, 144)
# 433                      93              3  (32, 332)   (138, 226)
# 932                      36              0  (36, 328)   (141, 223)
# 20                       45              1  (326, 38)   (216, 148)
# 893                      57              3  (39, 325)   (143, 221)
# 758                      52              1  (321, 43)   (206, 158)
# 182                      44              0  (46, 318)   (172, 192)
# 54                       53              1  (315, 49)   (218, 146)
#
#     player1_sum player2_sum winner        outcome winning_total losing_total
# 395           0         364      1  Player 2 wins           364            0
# 469          18         346      1  Player 2 wins           346           18
# 979         341          23      0  Player 1 wins           341           23
# 433          32         332      1  Player 2 wins           332           32
# 932          36         328      1  Player 2 wins           328           36
# 20          326          38      0  Player 1 wins           326           38
# 893          39         325      1  Player 2 wins           325           39
# 758         321          43      0  Player 1 wins           321           43
# 182          46         318      1  Player 2 wins           318           46
# 54          315          49      0  Player 1 wins           315           49

# %% [markdown]
# ## Exercise #4

# %% [markdown]
# ### Step 4.1

# %%
df_trial['Number of ties'].value_counts()
# Out:
# 0    508
# 1    314
# 2    134
# 3     38
# 4      5
# 6      1
# Name: Number of ties, dtype: int64

# %% [markdown]
# ### Step 4.2

# %%
max_tie = df_trial['Number of ties'].value_counts()

# %%
counter = max(max_tie.index)

# %%
df_trial['Maximum round total won'].mean()
# Out:
# 48.964

# %%
print('Number of Ties     Mean of round maximum')
for i in range(counter+1):
    print(str(i)+"                   " +str(df_trial.loc[df_trial['Number of ties']==i,'Maximum round total won'].mean()))
# Out:
# Number of Ties     Mean of round maximum
# 0                   40.389763779527556
# 1                   55.57324840764331
# 2                   59.507462686567166
# 3                   68.86842105263158
# 4                   68.0
# 5                   nan
# 6                   65.0

# %% [markdown]
# #### We can see, as number of ties are increasing, the mean of round maximum is increasing which is logical as person will get more cards to break the tie and the maximum of round will increase.
